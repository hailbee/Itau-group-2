# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import cosine

df = pd.read_parquet("validate_pairs_with_siglip_embeddings.parquet")

# Extract embedding column names
fraud_cols = [col for col in df.columns if col.startswith('fraud_emb_') and col != 'fraud_emb_']
real_cols = [col for col in df.columns if col.startswith('real_emb_') and col != 'real_emb_']

# Sort by numeric suffix to ensure correct order
fraud_cols = sorted(fraud_cols, key=lambda x: int(x.split('_')[2]))
real_cols = sorted(real_cols, key=lambda x: int(x.split('_')[2]))

# print out the average cosine similarity between the two embeddings for all rows with label 0
label_0_df = df[df['label'] == 0]
cosine_similarities_0 = []
for index, row in label_0_df.iterrows():
    fraud_emb = row[fraud_cols].to_numpy()
    real_emb = row[real_cols].to_numpy()
    # compute cosine similarity
    cos_sim = 1 - cosine(fraud_emb, real_emb)
    cosine_similarities_0.append(cos_sim)
print(f"Average Cosine Similarity (label 0): {np.mean(cosine_similarities_0)}")

# then, print out the average cosine similarity between the two embeddings for all rows with label 1
label_1_df = df[df['label'] == 1]
cosine_similarities_1 = []
for index, row in label_1_df.iterrows():
    fraud_emb = row[fraud_cols].to_numpy()
    real_emb = row[real_cols].to_numpy()
    # compute cosine similarity
    cos_sim = 1 - cosine(fraud_emb, real_emb)
    cosine_similarities_1.append(cos_sim)
print(f"Average Cosine Similarity (label 1): {np.mean(cosine_similarities_1)}")
# Out:
# Average Cosine Similarity (label 0): 0.7513720652058201
# Average Cosine Similarity (label 1): 0.9179862967287405

# %%
import re
import numpy as np
import pandas as pd
df = pd.read_parquet("validate_pairs_with_siglip_embeddings.parquet")
# ----------------------------
# Utilities
# ----------------------------
def _sorted_prefixed_cols(df: pd.DataFrame, prefix: str):
    # expects suffixes like prefix + "0", "1", ...
    pat = re.compile(rf"^{re.escape(prefix)}(-?\d+)$")
    cols = []
    for c in df.columns:
        if isinstance(c, str):
            m = pat.match(c)
            if m:
                cols.append((int(m.group(1)), c))
    if not cols:
        raise KeyError(f"No columns found with prefix '{prefix}'")
    cols.sort(key=lambda t: t[0])
    return [c for _, c in cols]

def l2_normalize(X: np.ndarray, eps: float = 1e-12) -> np.ndarray:
    n = np.linalg.norm(X, axis=1, keepdims=True)
    return X / np.maximum(n, eps)

def cosine_and_distance(fraud: np.ndarray, real: np.ndarray):
    f = l2_normalize(fraud.astype(np.float32, copy=False))
    r = l2_normalize(real.astype(np.float32, copy=False))
    cos = np.sum(f * r, axis=1)  # per-row cosine
    # Numerical safety: clip to [-1, 1]
    cos = np.clip(cos, -1.0, 1.0)
    d = np.sqrt(np.maximum(2.0 - 2.0 * cos, 0.0))
    return cos, d

def summarize_quantiles(x: np.ndarray, name: str, qs=(0.01,0.05,0.1,0.25,0.5,0.75,0.9,0.95,0.99)):
    x = np.asarray(x)
    out = {f"{name}_q{int(q*100):02d}": float(np.quantile(x, q)) for q in qs}
    out[f"{name}_mean"] = float(np.mean(x))
    out[f"{name}_std"]  = float(np.std(x))
    return out

# ----------------------------
# Margin picker
# ----------------------------
def pick_margin_from_df(
    df: pd.DataFrame,
    fraud_prefix: str,
    real_prefix: str,
    label_col: str = "label",
    # choose which negative distance quantile defines the margin:
    neg_quantile: float = 0.75,
    # optional safety clamps (highly recommended):
    min_margin: float = 0.3,
    max_margin: float = 1.9,
):
    y = df[label_col].astype(int).to_numpy()

    fraud_cols = _sorted_prefixed_cols(df, fraud_prefix)
    real_cols  = _sorted_prefixed_cols(df, real_prefix)
    if len(fraud_cols) != len(real_cols):
        raise ValueError(f"Dim mismatch: {len(fraud_cols)} vs {len(real_cols)}")

    fraud = df[fraud_cols].to_numpy(dtype=np.float32, copy=False)
    real  = df[real_cols].to_numpy(dtype=np.float32, copy=False)

    cos, d = cosine_and_distance(fraud, real)

    d_neg = d[y == 0]
    d_pos = d[y == 1]
    if d_neg.size == 0 or d_pos.size == 0:
        raise ValueError("Need both label 0 and label 1 rows to pick margin robustly.")

    # Core recommendation: quantile of negative distances
    raw_margin = float(np.quantile(d_neg, neg_quantile))
    margin = float(np.clip(raw_margin, min_margin, max_margin))

    # Diagnostics: how many negatives would be active under hinge for some margins?
    candidates = sorted(set([
        float(np.quantile(d_neg, q)) for q in (0.5, 0.75, 0.9, 0.95)
    ] + [margin, 0.6, 0.8, 1.0, 1.2]))
    candidates = [c for c in candidates if np.isfinite(c)]

    active_table = []
    for m in candidates:
        active_frac = float(np.mean(d_neg < m))   # negatives that still incur loss
        active_table.append((m, active_frac))

    print("\n==============================")
    print(" MARGIN SELECTION DIAGNOSTICS")
    print("==============================")
    print(f"Fraud prefix: {fraud_prefix} | Real prefix: {real_prefix}")
    print(f"Embedding dim: {fraud.shape[1]} | N={len(df)}")
    print(f"Label counts: n0={int(np.sum(y==0))} | n1={int(np.sum(y==1))}")

    # Summaries
    for k, v in summarize_quantiles(d_neg, "d_neg").items():
        print(f"{k}: {v}")
    for k, v in summarize_quantiles(d_pos, "d_pos").items():
        print(f"{k}: {v}")

    # Recommended margin
    print("\n--- Recommendation ---")
    print(f"raw margin = q{int(neg_quantile*100)}(d_neg) = {raw_margin:.6f}")
    print(f"clamped to [{min_margin}, {max_margin}] => margin = {margin:.6f}")

    # Active negative fractions
    print("\n--- Active negatives under hinge: frac(d_neg < margin) ---")
    for m, frac in active_table:
        print(f"margin={m:.6f} -> active_neg_frac={frac:.3f}")

    print("==============================\n")
    return margin

# ----------------------------
# Example usage
# ----------------------------
margin = pick_margin_from_df(df, fraud_prefix="fraud_emb_", real_prefix="real_emb_", label_col="label")
print("Use this margin in training:", margin)
# Out:
# ...
#  MARGIN SELECTION DIAGNOSTICS
# ...
# Fraud prefix: fraud_emb_ | Real prefix: real_emb_
# Embedding dim: 768 | N=9999
# Label counts: n0=3571 | n1=6428
# d_neg_q01: 0.4710727334022522
# d_neg_q05: 0.5453044772148132
# d_neg_q10: 0.5760542154312134
# d_neg_q25: 0.6341327428817749
# d_neg_q50: 0.699133574962616
# d_neg_q75: 0.7655516862869263
# d_neg_q90: 0.8203191161155701
# d_neg_q95: 0.8536616563796997
# d_neg_q99: 0.9094284176826477
# d_neg_mean: 0.698676347732544
# d_neg_std: 0.09543623775243759
# d_pos_q01: 0.03488533943891525
# d_pos_q05: 0.1004176139831543
# d_pos_q10: 0.14377208054065704
# d_pos_q25: 0.23929890990257263
# d_pos_q50: 0.37842267751693726
# d_pos_q75: 0.49482983350753784
# d_pos_q90: 0.5814834237098694
# d_pos_q95: 0.6300879120826721
# d_pos_q99: 0.7091063261032104
# d_pos_mean: 0.3698880076408386
# d_pos_std: 0.16495850682258606
#
# --- Recommendation ---
# raw margin = q75(d_neg) = 0.765552
# clamped to [0.3, 1.9] => margin = 0.765552
#
# ...

# %%
print(df.head())
# Out:
#   fraudulent_name    real_name  label  fraud_aligned_0  real_aligned_0  \
# 0      meĝaĉriŧic   megacritic      1        -0.003817       -0.003773
# 1         thedodo    queveohoy      0        -0.004744       -0.003717
# 2       alrnundoz      almundo      1        -0.004316       -0.004205
# 3          nijobs      topjobs      0        -0.003844       -0.003677
# 4     trhonethrow  thronethrow      1        -0.004280       -0.004093
#
#    fraud_aligned_1  real_aligned_1  fraud_aligned_2  real_aligned_2  \
# 0         0.001740        0.001791         0.010799        0.011028
# 1         0.002584        0.002196         0.011642        0.011145
# 2         0.002402        0.002446         0.011062        0.010230
# 3         0.002050        0.002104         0.009422        0.010252
# 4         0.002641        0.002594         0.011654        0.011328
#
#    fraud_aligned_3  ...  fraud_aligned_123  real_aligned_123  \
# 0         0.003925  ...          -0.008329         -0.008390
# ...

# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import cosine

df = pd.read_parquet("golden_embeddings_validate.parquet")

# Extract embedding column names
fraud_cols = [col for col in df.columns if col.startswith("fraud_aligned_") and col != "fraud_aligned_"]
real_cols  = [col for col in df.columns if col.startswith("real_aligned_") and col != "real_aligned_"]

# Sort by numeric suffix
fraud_cols = sorted(fraud_cols, key=lambda x: int(x.split("_")[2]))
real_cols  = sorted(real_cols, key=lambda x: int(x.split("_")[2]))

def safe_cosine_similarity(a, b, eps=1e-12):
    na = np.linalg.norm(a)
    nb = np.linalg.norm(b)
    if na < eps or nb < eps:
        return np.nan   # skip bad rows
    return 1 - cosine(a, b)

# label 0
label_0_df = df[df["label"] == 0]
cosine_similarities_0 = []
for _, row in label_0_df.iterrows():
    fraud_emb = row[fraud_cols].to_numpy(dtype=np.float32)
    real_emb  = row[real_cols].to_numpy(dtype=np.float32)

    cos_sim = safe_cosine_similarity(fraud_emb, real_emb)
    cosine_similarities_0.append(cos_sim)

print(f"Average Cosine Similarity (label 0): {np.nanmean(cosine_similarities_0)}")
print(f"Skipped rows (label 0): {np.isnan(cosine_similarities_0).sum()}")

# label 1
label_1_df = df[df["label"] == 1]
cosine_similarities_1 = []
for _, row in label_1_df.iterrows():
    fraud_emb = row[fraud_cols].to_numpy(dtype=np.float32)
    real_emb  = row[real_cols].to_numpy(dtype=np.float32)

    cos_sim = safe_cosine_similarity(fraud_emb, real_emb)
    cosine_similarities_1.append(cos_sim)

print(f"Average Cosine Similarity (label 1): {np.nanmean(cosine_similarities_1)}")
print(f"Skipped rows (label 1): {np.isnan(cosine_similarities_1).sum()}")
# Out:
# Average Cosine Similarity (label 0): 0.879941999912262
# Skipped rows (label 0): 0
# Average Cosine Similarity (label 1): 0.9825295209884644
# Skipped rows (label 1): 0

# %%
print(df.head())
# Out:
#   fraudulent_name    real_name  label  fraud_emb_0  fraud_emb_1  fraud_emb_2  \
# 0      meĝaĉriŧic   megacritic    1.0     0.000600    -0.007896    -0.003164
# 1         thedodo    queveohoy    0.0    -0.004787    -0.028183    -0.025284
# 2       alrnundoz      almundo    1.0    -0.027649    -0.007935     0.014977
# 3          nijobs      topjobs    0.0    -0.000916    -0.013054     0.009880
# 4     trhonethrow  thronethrow    1.0     0.030640    -0.025146    -0.027786
#
#    fraud_emb_3  fraud_emb_4  fraud_emb_5  fraud_emb_6  ...  real_emb_758  \
# 0     0.000899    -0.065735     0.020599    -0.043213  ...     -0.014992
# 1     0.005352    -0.012238     0.036560    -0.039368  ...     -0.006527
# 2    -0.020599    -0.038940     0.034180     0.044586  ...     -0.032898
# 3     0.021088    -0.030075    -0.007202     0.016129  ...     -0.017349
# 4    -0.008110    -0.023529     0.031403    -0.000193  ...     -0.023560
#
# ...

# %%
print(df.head())
# Out:
#   fraudulent_name    real_name  label  fraud_emb_0  fraud_emb_1  fraud_emb_2  \
# 0      meĝaĉriŧic   megacritic    1.0     0.000600    -0.007896    -0.003164
# 1         thedodo    queveohoy    0.0    -0.004787    -0.028183    -0.025284
# 2       alrnundoz      almundo    1.0    -0.027649    -0.007935     0.014977
# 3          nijobs      topjobs    0.0    -0.000916    -0.013054     0.009880
# 4     trhonethrow  thronethrow    1.0     0.030640    -0.025146    -0.027786
#
#    fraud_emb_3  fraud_emb_4  fraud_emb_5  fraud_emb_6  ...  real_emb_758  \
# 0     0.000899    -0.065735     0.020599    -0.043213  ...     -0.014992
# 1     0.005352    -0.012238     0.036560    -0.039368  ...     -0.006527
# 2    -0.020599    -0.038940     0.034180     0.044586  ...     -0.032898
# 3     0.021088    -0.030075    -0.007202     0.016129  ...     -0.017349
# 4    -0.008110    -0.023529     0.031403    -0.000193  ...     -0.023560
#
# ...

# %%
# =========================
# PCA/Whitening Diagnostics + Transform for interleaved columns like:
#   fraud_aligned_0, real_aligned_0, fraud_aligned_1, real_aligned_1, ...
#
# Produces:
#   - metrics before
#   - PCA(+whiten) transform
#   - metrics after
#   - adds columns: fraud_z_0..k-1 and real_z_0..k-1 to df (via concat, no fragmentation)
# =========================

import re
import numpy as np
import pandas as pd

from sklearn.decomposition import PCA
from sklearn.metrics import roc_auc_score

# -------------------------
# Config (edit if needed)
# -------------------------
LABEL_COL = "label"

# These match your screenshot:
FRAUD_PREFIX = "fraud_aligned_"
REAL_PREFIX  = "real_aligned_"

# If you want auto-detection fallback (e.g., fraud_emb_/real_emb_), you can add those below.
ALT_PREFIXES = [
    ("fraud_emb_", "real_emb_"),
]

K_PCA = 64
WHITEN_EPS = 1e-6

RANDOM_PAIR_SAMPLES = 200_000
NN_SUBSAMPLE = 5000
PCA_FIT_SUBSAMPLE = 200_000
RNG_SEED = 0

rng = np.random.default_rng(RNG_SEED)

# -------------------------
# Helpers
# -------------------------
def _safe_to_numpy(df_cols: pd.DataFrame) -> np.ndarray:
    x = df_cols.to_numpy(dtype=np.float32, copy=False)
    x = np.nan_to_num(x, nan=0.0, posinf=0.0, neginf=0.0)
    return x

def l2_normalize(X: np.ndarray, eps: float = 1e-12) -> np.ndarray:
    n = np.linalg.norm(X, axis=1, keepdims=True)
    return X / np.maximum(n, eps)

def cosine_pairs(A: np.ndarray, B: np.ndarray) -> np.ndarray:
    return np.sum(l2_normalize(A) * l2_normalize(B), axis=1)

def random_pair_cosines(X: np.ndarray, n_pairs: int, rng: np.random.Generator) -> np.ndarray:
    Xn = l2_normalize(X)
    n = Xn.shape[0]
    if n < 2:
        return np.array([], dtype=np.float32)
    i = rng.integers(0, n, size=n_pairs, endpoint=False)
    j = rng.integers(0, n, size=n_pairs, endpoint=False)
    same = (i == j)
    if np.any(same):
        j[same] = (j[same] + 1) % n
    return np.sum(Xn[i] * Xn[j], axis=1)

def effective_rank_from_cov(X: np.ndarray) -> dict:
    Xc = X - X.mean(axis=0, keepdims=True)
    n = Xc.shape[0]
    if n <= 1:
        return dict(effective_rank=np.nan, top1_var_frac=np.nan)
    cov = (Xc.T @ Xc) / (n - 1)
    eigvals = np.linalg.eigvalsh(cov).astype(np.float64)
    eigvals = np.maximum(eigvals, 0.0)
    s = eigvals.sum()
    if s <= 0:
        return dict(effective_rank=0.0, top1_var_frac=np.nan)
    r_eff = (s * s) / np.sum(eigvals * eigvals + 1e-30)
    top1 = eigvals[-1] / s
    return dict(effective_rank=float(r_eff), top1_var_frac=float(top1))

def nn_cosine_stats(X: np.ndarray, subsample: int, rng: np.random.Generator) -> dict:
    Xn = l2_normalize(X)
    n = Xn.shape[0]
    if n < 2:
        return dict(nn_cos_mean=np.nan, nn_cos_p50=np.nan, nn_cos_p90=np.nan)
    m = min(subsample, n)
    idx = rng.choice(n, size=m, replace=False)
    Y = Xn[idx]
    S = Y @ Y.T
    np.fill_diagonal(S, -np.inf)
    nn = np.max(S, axis=1)
    return dict(
        nn_cos_mean=float(np.mean(nn)),
        nn_cos_p50=float(np.median(nn)),
        nn_cos_p90=float(np.quantile(nn, 0.90)),
    )

def auc_with_direction(y: np.ndarray, score: np.ndarray) -> dict:
    y = y.astype(int)
    if len(np.unique(y)) < 2:
        return dict(auc=np.nan, direction="degenerate_labels")
    auc_pos = roc_auc_score(y, score)
    auc_neg = roc_auc_score(y, -score)
    if auc_pos >= auc_neg:
        return dict(auc=float(auc_pos), direction="score_higher_for_label1")
    else:
        return dict(auc=float(auc_neg), direction="score_lower_for_label1 (use -score)")

def report_metrics(real_emb: np.ndarray, fraud_emb: np.ndarray, y: np.ndarray,
                   n_rand_pairs: int, nn_subsample: int, rng: np.random.Generator,
                   tag: str = "") -> dict:
    X_all = np.vstack([real_emb, fraud_emb])
    pair_cos = cosine_pairs(fraud_emb, real_emb)
    rand_cos = random_pair_cosines(X_all, n_rand_pairs, rng)
    spec = effective_rank_from_cov(X_all)
    nn_stats = nn_cosine_stats(X_all, nn_subsample, rng)

    y = y.astype(int)
    pos = (y == 1)
    neg = (y == 0)

    def _mean_std(x):
        return float(np.mean(x)), float(np.std(x))

    m1, s1 = _mean_std(pair_cos[pos]) if np.any(pos) else (np.nan, np.nan)
    m0, s0 = _mean_std(pair_cos[neg]) if np.any(neg) else (np.nan, np.nan)

    auc_info = auc_with_direction(y, pair_cos)

    return {
        "tag": tag,
        "n_rows": int(real_emb.shape[0]),
        "embed_dim": int(real_emb.shape[1]),
        "rand_pair_cos_mean": float(np.mean(rand_cos)) if rand_cos.size else np.nan,
        "rand_pair_cos_std": float(np.std(rand_cos)) if rand_cos.size else np.nan,
        "rand_pair_cos_p10": float(np.quantile(rand_cos, 0.10)) if rand_cos.size else np.nan,
        "rand_pair_cos_p50": float(np.quantile(rand_cos, 0.50)) if rand_cos.size else np.nan,
        "rand_pair_cos_p90": float(np.quantile(rand_cos, 0.90)) if rand_cos.size else np.nan,
        **nn_stats,
        "effective_rank": spec["effective_rank"],
        "top1_var_frac": spec["top1_var_frac"],
        "pair_cos_mean_label1": m1,
        "pair_cos_std_label1": s1,
        "pair_cos_mean_label0": m0,
        "pair_cos_std_label0": s0,
        "pair_cos_mean_diff_(label1-label0)": float(m1 - m0),
        "pair_cos_auc_(best_direction)": auc_info["auc"],
        "auc_direction": auc_info["direction"],
        # Also print the "exact evaluator2.py behavior" AUC (no flipping)
        "pair_cos_auc_(raw_no_flip_like_evaluator2)": float(roc_auc_score(y, pair_cos)) if len(np.unique(y)) > 1 else np.nan,
    }

# -------------------------
# Column extraction (prefix + integer suffix), works for interleaving
# -------------------------
_int_suffix_re_cache = {}

def _sorted_prefixed_cols(df: pd.DataFrame, prefix: str) -> list[str]:
    # Matches prefix + integer suffix, e.g. fraud_aligned_0
    if prefix not in _int_suffix_re_cache:
        _int_suffix_re_cache[prefix] = re.compile(rf"^{re.escape(prefix)}(-?\d+)$")
    pat = _int_suffix_re_cache[prefix]

    cols = []
    for c in df.columns:
        if isinstance(c, str):
            m = pat.match(c)
            if m:
                cols.append((int(m.group(1)), c))
    if not cols:
        return []
    cols.sort(key=lambda t: t[0])
    return [c for _, c in cols]

def extract_embeddings(df: pd.DataFrame,
                       label_col: str = LABEL_COL,
                       fraud_prefix: str = FRAUD_PREFIX,
                       real_prefix: str = REAL_PREFIX):
    if label_col not in df.columns:
        raise KeyError(f"label_col='{label_col}' not found in df.columns")

    # Try primary prefixes
    fraud_cols = _sorted_prefixed_cols(df, fraud_prefix)
    real_cols  = _sorted_prefixed_cols(df, real_prefix)

    # If not found, try alternates
    if not fraud_cols or not real_cols:
        for fp, rp in ALT_PREFIXES:
            f_try = _sorted_prefixed_cols(df, fp)
            r_try = _sorted_prefixed_cols(df, rp)
            if f_try and r_try:
                fraud_cols, real_cols = f_try, r_try
                fraud_prefix, real_prefix = fp, rp
                break

    if not fraud_cols or not real_cols:
        raise KeyError(
            f"Could not find embedding columns. Tried fraud_prefix='{fraud_prefix}', real_prefix='{real_prefix}', "
            f"and alternates={ALT_PREFIXES}."
        )

    if len(fraud_cols) != len(real_cols):
        raise ValueError(f"fraud dim != real dim: {len(fraud_cols)} vs {len(real_cols)}")

    y = df[label_col].astype(int).to_numpy()
    fraud_emb = _safe_to_numpy(df[fraud_cols])
    real_emb  = _safe_to_numpy(df[real_cols])

    return y, real_emb, fraud_emb, real_cols, fraud_cols, label_col, real_prefix, fraud_prefix

# =========================
# RUN
# =========================
y, real_emb, fraud_emb, real_cols, fraud_cols, label_col, real_prefix_used, fraud_prefix_used = extract_embeddings(df)

print("[INFO] Using prefixes:", {"real": real_prefix_used, "fraud": fraud_prefix_used})
print("[INFO] real_emb shape:", real_emb.shape, "| fraud_emb shape:", fraud_emb.shape)

# 1) Metrics BEFORE
before = report_metrics(
    real_emb=real_emb,
    fraud_emb=fraud_emb,
    y=y,
    n_rand_pairs=RANDOM_PAIR_SAMPLES,
    nn_subsample=NN_SUBSAMPLE,
    rng=rng,
    tag="before"
)

print("\n=== METRICS: BEFORE PCA/WHITEN ===")
for k, v in before.items():
    if k == "tag":
        continue
    print(f"{k}: {v}")

# 2) PCA(+whiten) on the combined image embedding cloud
X_all = np.vstack([real_emb, fraud_emb])  # (2N, d)
n_all = X_all.shape[0]
m_fit = min(PCA_FIT_SUBSAMPLE, n_all)
fit_idx = rng.choice(n_all, size=m_fit, replace=False) if m_fit < n_all else None
X_fit = X_all[fit_idx] if fit_idx is not None else X_all

mu = X_fit.mean(axis=0, keepdims=True).astype(np.float32)

k = min(K_PCA, X_all.shape[1])
pca = PCA(n_components=k, svd_solver="auto", random_state=RNG_SEED)
pca.fit(X_fit - mu)

components = pca.components_.astype(np.float32)      # (k, d)
eigvals = pca.explained_variance_.astype(np.float32) # (k,)

def pca_whiten_transform(X: np.ndarray) -> np.ndarray:
    Xc = (X - mu).astype(np.float32, copy=False)
    U = Xc @ components.T
    U = U / np.sqrt(eigvals.reshape(1, -1) + WHITEN_EPS)
    U = l2_normalize(U)
    return U

real_z  = pca_whiten_transform(real_emb)
fraud_z = pca_whiten_transform(fraud_emb)

# 3) Metrics AFTER
after = report_metrics(
    real_emb=real_z,
    fraud_emb=fraud_z,
    y=y,
    n_rand_pairs=RANDOM_PAIR_SAMPLES,
    nn_subsample=NN_SUBSAMPLE,
    rng=rng,
    tag="after_pca_whiten"
)

print("\n=== METRICS: AFTER PCA/WHITEN ===")
for k, v in after.items():
    if k == "tag":
        continue
    print(f"{k}: {v}")

# 4) Side-by-side deltas
summary_keys = [
    "rand_pair_cos_mean", "rand_pair_cos_std",
    "nn_cos_mean", "nn_cos_p50", "nn_cos_p90",
    "effective_rank", "top1_var_frac",
    "pair_cos_mean_diff_(label1-label0)",
    "pair_cos_auc_(best_direction)",
    "pair_cos_auc_(raw_no_flip_like_evaluator2)",
]

print("\n=== DELTAS (after - before) ===")
for k in summary_keys:
    b = before.get(k, np.nan)
    a = after.get(k, np.nan)
    d = float(a) - float(b) if np.isfinite(a) and np.isfinite(b) else np.nan
    print(f"{k}: before={b} | after={a} | delta={d}")

# 5) Add transformed columns to df WITHOUT fragmentation
new_cols = {}
for j in range(k):
    new_cols[f"real_z_{j}"]  = real_z[:, j]
    new_cols[f"fraud_z_{j}"] = fraud_z[:, j]
df = pd.concat([df, pd.DataFrame(new_cols, index=df.index)], axis=1)

print("\nDone. Transformed embeddings added as real_z_* and fraud_z_* (df reassigned).")
# Out:
# [INFO] Using prefixes: {'real': 'real_emb_', 'fraud': 'fraud_emb_'}
# [INFO] real_emb shape: (9999, 768) | fraud_emb shape: (9999, 768)
#
# === METRICS: BEFORE PCA/WHITEN ===
# n_rows: 9999
# embed_dim: 768
# rand_pair_cos_mean: 0.6381473541259766
# rand_pair_cos_std: 0.06029559299349785
# rand_pair_cos_p10: 0.5608879327774048
# rand_pair_cos_p50: 0.6411466598510742
# rand_pair_cos_p90: 0.7111937999725342
# nn_cos_mean: 0.9290907979011536
# nn_cos_p50: 0.9712848663330078
# nn_cos_p90: 0.9999997615814209
# effective_rank: 103.87093366359879
# top1_var_frac: 0.05322280929106418
# pair_cos_mean_label1: 0.917985737323761
# pair_cos_std_label1: 0.06208432838320732
# pair_cos_mean_label0: 0.7513716816902161
# pair_cos_std_label0: 0.0664217546582222
# pair_cos_mean_diff_(label1-label0): 0.16661405563354492
# pair_cos_auc_(best_direction): 0.9620082661319483
# auc_direction: score_higher_for_label1
# pair_cos_auc_(raw_no_flip_like_evaluator2): 0.9620082661319483
#
# ...

# %%
# shuffle and take first 100000 rows
df_sampled = df_full.sample(frac=1, random_state=42)
df_sampled = df_sampled.head(100000)
df_sampled.to_parquet("/Users/a../Downloads/train_pairs_with_siglip_embeddings_100k.parquet")

# %%
import pandas as pd
df_full = pd.read_parquet("/Users/a../Downloads/train_hard_100k.parquet")
print(df_full.head())
print(len(df_full))
# Out:
#   fraudulent_name      real_name  label  fraud_emb_0  fraud_emb_1  \
# 0        ėbooķ-dĺ       ebook-dl      1    -0.000314    -0.036652
# 1       miyazikig       miyazaki      1     0.021469    -0.016296
# 2         suƥfree        supfree      1     0.018066    -0.038757
# 3  ƀharatstuudent  bharatstudent      1     0.011322    -0.027512
# 4        gamėzoné       gamezone      1     0.020065    -0.024521
#
#    fraud_emb_2  fraud_emb_3  fraud_emb_4  fraud_emb_5  fraud_emb_6  ...  \
# 0    -0.018051     0.015854    -0.041321    -0.002714     0.006245  ...
# 1     0.007122     0.027069    -0.048218     0.005432    -0.015747  ...
# 2     0.009338    -0.035126    -0.016144     0.013313    -0.038361  ...
# 3     0.006096     0.036133    -0.039612     0.045990     0.016617  ...
# 4     0.008995     0.008148    -0.037506     0.020050     0.019257  ...
#
#    real_emb_759  real_emb_760  real_emb_761  real_emb_762  real_emb_763  \
# ...

# %%
# view unique values in cosine_similarity column
print(df_full['cosine_similarity'].unique())
# Out:
# [      nan 0.9003011 0.911442  ... 0.8719931 0.9084407 0.8784081]

# %%
# print the 3rd row
print(df_full.iloc[3])
# Out:
# fraudulent_name      ƀharatstuudent
# real_name             bharatstudent
# label                             1
# fraud_emb_0                0.011322
# fraud_emb_1               -0.027512
#                           ...
# real_emb_764              -0.012413
# real_emb_765                0.00985
# real_emb_766              -0.043488
# real_emb_767                0.03302
# cosine_similarity               NaN
# Name: 3, Length: 1540, dtype: object

# %%
# print total number of nan in 3rd row
print(df_full.iloc[3].isna().sum())

# print total number of inf in 3rd row
print((df_full.iloc[3] == float('inf')).sum())

#Index of embedding_0: 3
#Index of embedding_767: 770
#Index of real_embedding_0: 771
#Index of real_embedding_767: 1538

# extract embedding vectors from 3rd row
# extract real embedding vectors from 3rd row

embedding_0 = df_full.iloc[3, 3:771].to_numpy()
real_embedding_0 = df_full.iloc[3, 771:1539].to_numpy()

print(len(embedding_0))
# Out:
# 1
# 0
# 768

# %%
# convert to 1d vectors
embedding_0 = embedding_0.flatten()
real_embedding_0 = real_embedding_0.flatten()

# %%
from scipy.spatial.distance import cosine

print("Cosine similarity:", 1 - cosine(embedding_0, real_embedding_0))
# Out:
# Cosine similarity: 0.9853617

# %%
import torch.nn.functional as F
import torch
import numpy as np

embedding_0 = np.stack(embedding_0) 
tensor1 = torch.from_numpy(embedding_0)
real_embedding_0 = np.stack(real_embedding_0) 
tensor2 = torch.from_numpy(real_embedding_0)  

cosine_sim = F.cosine_similarity(tensor1, tensor2, dim=0)
print("Cosine similarity (PyTorch):", cosine_sim.item())
# Out:
# Cosine similarity (PyTorch): 0.9853616952896118

# %%
import pandas as pd
import numpy as np
import torch

PARQUET_PATH = "/Users/a../Downloads/train_pairs_with_siglip_embeddings.parquet"

FAKE_EMB_START = 3
FAKE_EMB_END = 771
REAL_EMB_START = 771
REAL_EMB_END = 1539

df = pd.read_parquet(PARQUET_PATH)

fake_np = df.iloc[:, FAKE_EMB_START:FAKE_EMB_END].to_numpy()
real_np = df.iloc[:, REAL_EMB_START:REAL_EMB_END].to_numpy()

fake_norms = np.linalg.norm(fake_np, axis=1)
real_norms = np.linalg.norm(real_np, axis=1)

bad_mask = (
    (fake_norms == 0) |
    (real_norms == 0) |
    np.isnan(fake_np).any(axis=1) |
    np.isnan(real_np).any(axis=1)
)

bad_indices = np.where(bad_mask)[0]

print(f"Total rows: {len(df)}")
print(f"Broken rows: {len(bad_indices)}")

for idx in bad_indices[:5]:
    print("\n" + "="*80)
    print(f"Row index: {idx}")
    print("Label:", df.iloc[idx]["label"])

    fake_vec = fake_np[idx]
    real_vec = real_np[idx]

    print("Fake embedding:")
    print("  norm:", np.linalg.norm(fake_vec))
    print("  min / max:", fake_vec.min(), fake_vec.max())
    print("  NaNs:", np.isnan(fake_vec).sum())

    print("Real embedding:")
    print("  norm:", np.linalg.norm(real_vec))
    print("  min / max:", real_vec.min(), real_vec.max())
    print("  NaNs:", np.isnan(real_vec).sum())

    print("\nRaw dataframe row:")
    print(df.iloc[idx])

for idx in bad_indices[:5]:
    row = df.iloc[idx]

    print("\n--- Metadata ---")
    for col in df.columns[:FAKE_EMB_START]:
        print(f"{col}: {row[col]}")
# Out:
# Total rows: 976122
# Broken rows: 0

# %%
import pandas as pd
df_full = pd.read_parquet("/Users/a../Downloads/train_shuffled_100k_with_neg_cosine.parquet")

# %%
# extract only rows where label is 0
# from this new df, print the fraudulent_name and real_name with highest cosine_similarity
df_label_0 = df_full[df_full['label'] == 0]
max_cosine_row = df_label_0.loc[df_label_0['cosine_similarity'].idxmax()]
print("Fraudulent Name:", max_cosine_row['fraudulent_name'])
print("Real Name:", max_cosine_row['real_name'])
print("Cosine Similarity:", max_cosine_row['cosine_similarity'])
# then, print the fraudulent_name and real_name with lowest cosine_similarity
min_cosine_row = df_label_0.loc[df_label_0['cosine_similarity'].idxmin()]
print("Fraudulent Name (min):", min_cosine_row['fraudulent_name'])
print("Real Name (min):", min_cosine_row['real_name'])
# Out:
# Fraudulent Name: ymall
# Real Name: ymail
# Cosine Similarity: 0.99311644
# Fraudulent Name (min): onlinecorrection
# Real Name (min): hotmail-iniciar-sesion

# %%
# print histogram distribution of cosine_similarity
import matplotlib.pyplot as plt
plt.hist(df_full['cosine_similarity'], bins=50)
plt.xlabel('Cosine Similarity')
plt.ylabel('Frequency')
plt.title('Distribution of Cosine Similarity')
plt.show()

# %%
import pandas as pd
import numpy as np
from collections import Counter

# print all unique column prefixes before the first number in the column names
PATH = "../text_to_image/Golden_and_Text/test_pairs_with_img_and_txt_embs.parquet"  # update if needed

df = pd.read_parquet(PATH)

prefixes = []
for col in df.columns:
    prefix = ''
    for char in col:
        if char.isdigit():
            break
        prefix += char
    prefixes.append(prefix)
print(Counter(prefixes))

print(df.head())
# Out:
# Counter({'fraud_txt_emb_': 768, 'real_txt_emb_': 768, 'fraud_aligned_': 128, 'real_aligned_': 128, 'fraudulent_name': 1, 'real_name': 1, 'label': 1})
#   fraudulent_name   real_name  label  fraud_aligned_0  real_aligned_0  \
# 0      mekwajisyo  meiwajisyo      1        -0.050095       -0.048045
# 1      meiawijsyo  meiwajisyo      1        -0.048981       -0.048045
# 2     meiwa-ijsoy  meiwajisyo      1        -0.048237       -0.048045
# 3      męiwajisyo  meiwajisyo      1        -0.047895       -0.048045
# 4      meįwąjisyo  meiwajisyo      1        -0.047856       -0.048045
#
#    fraud_aligned_1  real_aligned_1  fraud_aligned_2  real_aligned_2  \
# 0         0.026083        0.023699         0.152362        0.146468
# 1         0.023095        0.023699         0.145078        0.146468
# 2         0.023892        0.023699         0.146320        0.146468
# 3         0.023755        0.023699         0.146468        0.146468
# ...
